# %%
from pathlib import Path
import yaml
import os

# dataDir = Path("/css-data")
dataDir = Path("C:/Users/jason/Downloads/Yolov9_Fine_Tunne/yolov9/css-data")

num_classes = 10
classes = [
    "Hardhat",
    "Mask",
    "NO-Hardhat",
    "NO-Mask",
    "NO-Safety Vest",
    "Person",
    "Safety Cone",
    "Safety Vest",
    "Machinery",
    "Vehicle",
]

file_dict = {
    "train": os.path.join(dataDir, "train\\images"),
    "val": os.path.join(dataDir, "valid\\images"),
    "test": os.path.join(dataDir, "test\\images"),
    "nc": num_classes,
    "names": classes,
}

with open(os.path.join("data.yaml"), "w+") as f:
    yaml.dump(file_dict, f)

# %%
# import yaml
# import os

# file_dict = {
#     "train": os.path.join(dataDir, "train/images"),
#     "val": os.path.join(dataDir, "valid/images"),
#     "test": os.path.join(dataDir, "test/images"),
#     "nc": num_classes,
#     "names": classes,
# }

# with open(os.path.join("data.yaml"), "w+") as f:
#     yaml.dump(file_dict, f)

# %%
# !python train_dual.py --workers 4 --batch 16  --img 640 --epochs 1 --data ./data.yaml --weights ./yolov9c.pt --device 0 --cfg ./models/detect/yolov9.yaml --hyp ./data/hyps/hyp.scratch-high.yaml

# %%
from ultralytics import YOLO

# %%
# model = YOLO("./runs/train/exp3/weights/best_new.pt")

# %%
# model.predict(
#     "./css-data/test/images/004763_jpg.rf.46484e6ca73caeaa9de45822cf1085a9.jpg"
# )

# %%
model = YOLO("yolov9c.pt")

# %%
results = model.train(
    data="./data.yaml", epochs=50, imgsz=640, batch=32, workers=2, optimizer="AdamW"
)
# Out:
# Ultralytics YOLOv8.1.24 🚀 Python-3.11.7 torch-2.2.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# ...

# %%
model = YOLO("runs/detect/train2/weights/best.pt")

# %%
model.info()
# Out:
# YOLOv9c summary: 618 layers, 25536942 parameters, 0 gradients, 103.7 GFLOPs
# (618, 25536942, 0, 103.7216256)

# %%
model.predict(
    "./css-data/test/images/004763_jpg.rf.46484e6ca73caeaa9de45822cf1085a9.jpg"
)
# Out:
# image 1/1 c:\Users\jason\Downloads\Yolov9_Fine_Tunne\yolov9\css-data\test\images\004763_jpg.rf.46484e6ca73caeaa9de45822cf1085a9.jpg: 640x640 3 Hardhats, 2 NO-Masks, 3 NO-Safety Vests, 4 Persons, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Hardhat', 1: 'Mask', 2: 'NO-Hardhat', 3: 'NO-Mask', 4: 'NO-Safety Vest', 5: 'Person', 6: 'Safety Cone', 7: 'Safety Vest', 8: 'machinery', 9: 'vehicle'}
#  obb: None
#  orig_img: array([[[134, 149, 152],
#          [122, 137, 140],
#          [105, 120, 123],
#          ...,
#          [128, 140, 142],
#          [130, 139, 142],
#          [129, 138, 141]],
#
#         [[136, 151, 154],
#          [124, 139, 142],
#          [107, 122, 125],
#          ...,
#          [129, 141, 143],
#          [131, 140, 143],
# ...

# %%
from ultralytics import YOLO


model = YOLO("yolov9c.pt")

model.train(
    data="./data.yaml",
    epochs=100,
    imgsz=640,
    batch=32,
    workers=2,
    name="epochs_100",
    patience=10,  # early stopping patience
    save=True,
    optimizer="AdamW",
    verbose=True,
    plots=True,
)
# Out:
# Ultralytics YOLOv8.1.25 🚀 Python-3.11.7 torch-2.2.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# ...
